# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import *
from scipy import *

# %% [markdown]
# Finding 1: Gun control can't stop suicide. It only changes the methods of suicide.

# %%
#Data for finding1:
df = pd.read_csv('suicides_aus.csv')
df.head(5)
# Out:
#    year  suicides by firearm  suicides number
# 0  1993                  2.5             1687
# 1  1994                  2.4             1830
# 2  1995                  2.2             1873
# 3  1996                  2.1             1931
# 4  1997                  1.8             2143

# %%
#define variables
year = df["year"]
data1 = df["suicides number"]
data2 = df["suicides by firearm"]

# %%
#visualize it with line graph since we want to contrast the difference.

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('year')
ax1.set_ylabel('Australia suicides number', color=color)
ax1.plot(year, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Australia suicides by firearm', color=color)  # we already handled the x-label with ax1
ax2.plot(year, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

#add title
plt.title("Gun control in Australia can't stop suicide.\nIt only changes the methods of suicide.", fontsize=14)

#add a verticle line to indicate the timing of gun buyback program
plt.axvline(x="1996", color='blue', linestyle='--')

# Add legend:
plt.annotate('<- gun buyback program', (0, 0), (60, 200), color='blue', fontsize=13,
            xycoords='axes fraction', textcoords='offset points', va='top')
#add data source
plt.annotate('Data source: ABS', (0,0), (-60,-20), fontsize=8, 
             xycoords='axes fraction', textcoords='offset points', va='top')



fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# Finding2: Gun ownership has nothing to do with the crime rate.

# %%
#Data for finding2:
df2 = pd.read_csv('crime.csv')
df2.head(5)
# Out:
#        Country  Violent crime  Gun ownership
# 0        Japan            1.7            0.6
# 1     Portugal            2.6            8.5
# 2  Switzerland            5.2           45.7
# 3      Finland            8.5           29.2
# 4          USA            5.5           97.0

# %%
# create data
x = df2['Gun ownership']
y = df2['Violent crime']
z = df2['Gun ownership']
n = df2['Country'] 

# Change color with c and alpha. I map the color to the y axis value to indicate the violent crime rate.
plt.scatter(x, y, s=z*80, c=y, cmap="Reds", alpha=1.5, edgecolors="grey", linewidth=1)
 
# Add titles (main and on axis)
plt.xlabel("Gun ownership per 100,000")
plt.ylabel("Violent crime rate")
plt.title("Gun ownership has nothing to do with the crime rate.", fontsize=13)

#add data source and area description
plt.annotate('Data source: Swanson Research', (0,0), (-80,-20), fontsize=8, 
             xycoords='axes fraction', textcoords='offset points', va='top')

plt.annotate('Area = size of gun ownership', (0,0), (150,180), fontsize=8, 
             xycoords='axes fraction', textcoords='offset points', va='top')

#Add a legend to indicate the crime rate
plt.colorbar(label='Violent crime rate')
plt.clim(1, 12)

#add labels
plt.annotate('USA', (0,0), (240,90), fontsize=10, 
             xycoords='axes fraction', textcoords='offset points', va='top',color='blue')

plt.annotate('Australia', (0,0), (50,200), fontsize=10, 
             xycoords='axes fraction', textcoords='offset points', va='top',color='black')

plt.annotate('Japan', (0,0), (10,10), fontsize=10, 
             xycoords='axes fraction', textcoords='offset points', va='top',color='black')

plt.annotate('Portugal', (0,0), (30,19), fontsize=10, 
             xycoords='axes fraction', textcoords='offset points', va='top',color='black')

plt.annotate('Switzerland', (0,0), (110,85), fontsize=10, 
             xycoords='axes fraction', textcoords='offset points', va='top',color='black')

#plt.annotate('Spain', (0,0), (30,40), fontsize=10, 
             #xycoords='axes fraction', textcoords='offset points', va='top',color='black')

plt.annotate('Finland', (0,0), (75,157), fontsize=10, 
             xycoords='axes fraction', textcoords='offset points', va='top',color='black')

plt.annotate('Belgium', (0,0), (40,85), fontsize=10, 
             xycoords='axes fraction', textcoords='offset points', va='top',color='black')

#plt.annotate('France', (0,0), (75,100), fontsize=10, 
             #xycoords='axes fraction', textcoords='offset points', va='top',color='black')

plt.annotate('Poland', (0,0), (10,75), fontsize=10, 
             xycoords='axes fraction', textcoords='offset points', va='top',color='black')

plt.annotate('Denmark', (0,0), (25,115), fontsize=10, 
             xycoords='axes fraction', textcoords='offset points', va='top',color='black')

#plt.annotate('Canada', (0,0), (75,180), fontsize=10, 
             #xycoords='axes fraction', textcoords='offset points', va='top',color='black')

plt.annotate('Netherlands', (0,0), (5,135), fontsize=10, 
             xycoords='axes fraction', textcoords='offset points', va='top',color='black')

plt.annotate('Sweden', (0,0), (75,127), fontsize=10, 
             xycoords='axes fraction', textcoords='offset points', va='top',color='black')

plt.annotate('UK', (0,0), (17,180), fontsize=10, 
             xycoords='axes fraction', textcoords='offset points', va='top',color='black')

#plot the graph
fig.tight_layout()
plt.show()

# %% [markdown]
# Finding3: More guns, less crime.

# %%
#Data for finding3:
df3 = pd.read_csv('guns.csv')
df3.head(5)
# Out:
#    Year  Firearm Homicide Deaths Rate Manufactured Exported   Imported  \
# 0  1987                           5.2    3,559,663  288,045  1,063,513
# 1  1988                           5.6    3,963,877  257,182  1,276,268
# 2  1989                           5.9    4,418,393  261,282  1,007,781
# 3  1990                           6.5    3,959,968  361,625    843,809
# 4  1993                           7.0    5,055,637  431,204  3,043,321
#
#    Population million   new guns   total guns  total guns million  \
# 0                 242  4,335,131  191,651,477                 192
# 1                 245  4,982,963  196,634,440                 197
# 2                 247  5,164,892  201,799,332                 202
# 3                 250  4,442,152  206,241,484                 206
# 4                 260  7,667,754  224,410,591                 224
#
#    guns per person
# 0           0.7910
# 1           0.8042
# 2           0.8176
# 3           0.8262
# 4           0.8634

# %%
#define variables
year = df3["Year"]
data1 = df3["guns per person"]
data2 = df3["Firearm Homicide Deaths Rate"]

# %%
#visualize it with line graph since we want to contrast the difference.

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('year')
ax1.set_ylabel('guns per person in the US', color=color)
ax1.plot(year, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('US Firearm Homicide Deaths Rate', color=color)  # we already handled the x-label with ax1
ax2.plot(year, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

#add title
plt.title("More guns, less crime.", fontsize=16)

#add data source
plt.annotate('Data source: ATF', (0,0), (-60,-20), fontsize=8, 
             xycoords='axes fraction', textcoords='offset points', va='top')

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
#Data before 1992 seems not persuasive, I decided to delete them:D
df4 = pd.read_csv('guns2.csv')
df4.head(5)
# Out:
#    Year  Firearm Homicide Deaths Rate Manufactured Exported   Imported  \
# 0  1994                           6.7    5,173,217  404,473  1,880,902
# 1  1996                           5.2    3,854,439  331,997    881,578
# 2  1998                           4.3    3,713,590  203,344    999,810
# 3  2000                           3.8    3,793,541  172,627  1,096,782
# 4  2002                           4.1    3,366,895  150,756  1,629,237
#
#    Population million   new guns   total guns  total guns million  \
# 0                 263  6,649,646  231,060,237                 231
# 1                 269  4,404,020  240,459,782                 240
# 2                 276  4,510,056  249,227,676                 249
# 3                 282  4,717,696  258,664,600                 259
# 4                 288  4,845,376  267,636,916                 268
#
#    guns per person
# 0           0.8781
# 1           0.8926
# 2           0.9035
# 3           0.9167
# 4           0.9305

# %%
#define variables
year = df4["Year"]
data1 = df4["guns per person"]
data2 = df4["Firearm Homicide Deaths Rate"]

# %%
#visulize it with line graph since we want to contrast the difference.

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('year')
ax1.set_ylabel('guns per person in the US', color=color)
ax1.plot(year, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('US Firearm Homicide Deaths Rate', color=color)  # we already handled the x-label with ax1
ax2.plot(year, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

#add title
plt.title("More guns, less crime.", fontsize=16)

#add data source
plt.annotate('Data source: ATF', (0,0), (-60,-20), fontsize=8, 
             xycoords='axes fraction', textcoords='offset points', va='top')

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
